# %%
from IPython.display import HTML

table_html = """
<table style="width: 100%; border-collapse: collapse;", justify="center">
  <thead>
    <tr>
      <td style="text-align: center;">Thành viên</th>
      <td style="text-align: center;">Gặp những khó khăn gì?</th>
      <td style="text-align: center;">Đã học được những gì?</th>
      <td style="text-align: center;">(Cả nhóm) Nếu có thêm thời gian thì làm gì?</th>
    </tr>
  </thead>
  <tbody>
    <tr>
      <td> 21120110 <br> Nguyễn Tấn Phát</td>
      <td style="text-align: left;"> + Cần có thời gian để phát hiện lỗi và sửa chữa. </td>
      <td style="text-align: left;"> 
        + Kiến thức mới về các công cụ, các thư viện mạnh mẽ của Python cho khám phá dữ liệu phục vụ cho cách
        trả lời câu hỏi cũng như trích xuất tri thức trích  dữ liệu. <br> <br>
        + Các bước tiền xử lý dữ liệu đặc trưng cho việc tìm hiểu và khám phá dữ liệu.  </td>
      <td style="text-align: left;"> 
      + Áp dụng lý thuyết nâng cao về xác suất thống kê để khai thác chuyên sâu dữ liệu. </td>
    </tr>
    <tr>
      <td>21120115 <br> Nguyễn Trọng Phúc </td>
      <td style="text-align: left;">+ Trong quá trình đặt câu hỏi đề xuất: 
        số lượng thuộc tính tương đối hàn lâm và chuyên ngành,  
        do đó việc đặt câu hỏi phù hợp, 
        có ý nghĩa thực tế cần có sự tìm hiểu sâu rộng<br> 
      </td>
      <td style="text-align: left;">
      + Kỹ năng làm việc nhóm: phân công công việc, theo dõi tiến độ đồ án, quản lí thời gian,… <br> <br>
      + Nâng cao kỹ năng sử dụng Github trong việc quản lí đồ án, 
      trao đổi thông tin hiệu quả trong cập nhật thông tin đồ án. <br> <br>
      + Học thêm nhiều kinh nghiệm và kiến thức từ những thành viên khác trong nhóm.
      </td>
      <td style="text-align: left;">+ Nếu có thời gian sẽ bổ sung thêm những câu hỏi khó hơn, 
        giải quyết được những vấn đề phức tạp hơn</td>
    </tr>
    <tr>
      <td> 21120322 <br> Nguyễn Dương Trường Sinh</td>
      <td style="text-align: left;">
      + Đặt ra một bài toán khoa học dữ liệu sao cho gắn liền với thực tế.
      </td>
      <td style="text-align: left;">
      + Kiến thức mới về các công cụ, các thư viện mạnh mẽ của Python cho tiền xử lý dữ liệu phục vụ cho các
       thuật toán machine learning mô hình hóa dữ liệu. <br> <br>
      + Các bước tiền xử lý dữ liệu đặc trưng cho việc mô hình hóa dữ liệu đó.  <br> <br>
      </td>
      <td style="text-align: left;"> <br> <br>
      + Tìm hiểu sâu sắc về tiền xử lý cho mô hình học nhanh hơn.
      </td>
    </tr>

  </tbody>
</table>
"""

HTML(table_html)
# Out:
# <table style="width: 100%; border-collapse: collapse;", justify="center">
#   <thead>
#     <tr>
#       <td style="text-align: center;">Thành viên</th>
#       <td style="text-align: center;">Gặp những khó khăn gì?</th>
#       <td style="text-align: center;">Đã học được những gì?</th>
#       <td style="text-align: center;">(Cả nhóm) Nếu có thêm thời gian thì làm gì?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td> 21120110 <br> Nguyễn Tấn Phát</td>
#       <td style="text-align: left;"> + Cần có thời gian để phát hiện lỗi và sửa chữa. </td>
#       <td style="text-align: left;">
#         + Kiến thức mới về các công cụ, các thư viện mạnh mẽ của Python cho khám phá dữ liệu phục vụ cho cách
#         trả lời câu hỏi cũng như trích xuất tri thức trích  dữ liệu. <br> <br>
#         + Các bước tiền xử lý dữ liệu đặc trưng cho việc tìm hiểu và khám phá dữ liệu.  </td>
#       <td style="text-align: left;">
# ...
